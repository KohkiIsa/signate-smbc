# %% [markdown]
# <a href="https://colab.research.google.com/github/KohkiIsa/signate-smbc/blob/main/02_inference_main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 基本

# %%
import pandas as pd               # データを表のように扱うライブラリ
import numpy as np                # 数値計算を速くするライブラリ
import seaborn as sns             # きれいなグラフを簡単に作るライブラリ
import matplotlib.pyplot as plt   # グラフを作る基本的なライブラリ
# %matplotlib inline

from sklearn.model_selection import train_test_split  # データを訓練用と検証用に分ける
from sklearn.metrics import mean_squared_log_error # 評価の計算を行うライブラリ
import lightgbm as lgb # 予測モデルに関するライブラリ

# %%
# 文字化け対策（1/2）
# !pip install japanize-matplotlib #日本語表示対応ライブラリのインストール
# 文字化け対策（2/2）
import japanize_matplotlib #日本語表示対応ライブラリの読み込み

# %%
# どうせ使う
# !pip install catboost
import catboost

# %%
train = pd.read_csv('/content/SMBC_train.csv',index_col = 0)
test = pd.read_csv('/content/SMBC_test.csv',index_col = 0)

# %%
test.info()

# %%
test.isnull().sum()

# %%
missing_data = test[test['Latitude'].isna()]
# missing_dataをDataFrameにしたい
missing_data1 = pd.DataFrame(missing_data)
missing_data1

# %%
# City変数がOFFSHOREになっていて、LatitudeとLongitudeが欠損しているデータを埋めたい
import pandas as pd

# OFFSHOREの緯度と経度の値を定義
offshore_latitude = 29.937133
offshore_longitude = -90.061357

# CityがOFFSHOREで、LatitudeとLongitudeが欠損している行を埋める
test.loc[(test['City'] == 'OFFSHORE') & (test['Latitude'].isna()), 'Latitude'] = offshore_latitude
test.loc[(test['City'] == 'OFFSHORE') & (test['Longitude'].isna()), 'Longitude'] = offshore_longitude

# %%
# MACKSVILLEの緯度と経度の値を定義
MACKSVILLE_latitude = 37.957751
MACKSVILLE_longitude = -98.969033

# CityがMACKSVILLEで、LatitudeとLongitudeが欠損している行を埋める
test.loc[(test['City'] == 'MACKSVILLE') & (test['Latitude'].isna()), 'Latitude'] = MACKSVILLE_latitude
test.loc[(test['City'] == 'MACKSVILLE') & (test['Longitude'].isna()), 'Longitude'] = MACKSVILLE_longitude

# %%
# HARLANの緯度と経度の値を定義
HARLAN_latitude = 36.8352
HARLAN_longitude = -83.320417

# CityがMACKSVILLEで、LatitudeとLongitudeが欠損している行を埋める
test.loc[(test['City'] == 'HARLAN') & (test['Latitude'].isna()), 'Latitude'] = HARLAN_latitude
test.loc[(test['City'] == 'HARLAN') & (test['Longitude'].isna()), 'Longitude'] = HARLAN_longitude

# %%
# BRIGHTONの緯度と経度の値を定義
BRIGHTON_latitude = 39.959079
BRIGHTON_longitude = -104.801046

# CityがMACKSVILLEで、LatitudeとLongitudeが欠損している行を埋める
test.loc[(test['City'] == 'BRIGHTON') & (test['Latitude'].isna()), 'Latitude'] = BRIGHTON_latitude
test.loc[(test['City'] == 'BRIGHTON') & (test['Longitude'].isna()), 'Longitude'] = BRIGHTON_longitude

# %%
# NORAの緯度と経度の値を定義
NORA_latitude = 37.070006
NORA_longitude = -82.34685

# CityがMACKSVILLEで、LatitudeとLongitudeが欠損している行を埋める
test.loc[(test['City'] == 'NORA') & (test['Latitude'].isna()), 'Latitude'] = NORA_latitude
test.loc[(test['City'] == 'NORA') & (test['Longitude'].isna()), 'Longitude'] = NORA_longitude

# %%
# LOVINGTONの緯度と経度の値を定義
LOVINGTON_latitude = 32.944307
LOVINGTON_longitude = -103.350869

# CityがMACKSVILLEで、LatitudeとLongitudeが欠損している行を埋める
test.loc[(test['City'] == 'LOVINGTON') & (test['Latitude'].isna()), 'Latitude'] = LOVINGTON_latitude
test.loc[(test['City'] == 'LOVINGTON') & (test['Longitude'].isna()), 'Longitude'] = LOVINGTON_longitude

# %%
# EL PASOの緯度と経度の値を定義
EL_PASO_latitude = 31.811135
EL_PASO_longitude = -106.424517

# CityがMACKSVILLEで、LatitudeとLongitudeが欠損している行を埋める
test.loc[(test['City'] == 'EL PASO') & (test['Latitude'].isna()), 'Latitude'] = EL_PASO_latitude
test.loc[(test['City'] == 'EL PASO') & (test['Longitude'].isna()), 'Longitude'] = EL_PASO_longitude

# %%
# GILLETTEの緯度と経度の値を定義
GILLETTE_latitude = 44.272011
GILLETTE_longitude = -105.500366

# CityがMACKSVILLEで、LatitudeとLongitudeが欠損している行を埋める
test.loc[(test['City'] == 'GILLETTE') & (test['Latitude'].isna()), 'Latitude'] = GILLETTE_latitude
test.loc[(test['City'] == 'GILLETTE') & (test['Longitude'].isna()), 'Longitude'] = GILLETTE_longitude

# %%
# AZTECの緯度と経度の値を定義
AZTEC_latitude = 36.809006
AZTEC_longitude = -107.990193

# CityがMACKSVILLEで、LatitudeとLongitudeが欠損している行を埋める
test.loc[(test['City'] == 'AZTEC') & (test['Latitude'].isna()), 'Latitude'] = AZTEC_latitude
test.loc[(test['City'] == 'AZTEC') & (test['Longitude'].isna()), 'Longitude'] = AZTEC_longitude

# %%
# COUSHATTAの緯度と経度の値を定義
COUSHATTA_latitude = 32.025917
COUSHATTA_longitude = -93.341765

# CityがMACKSVILLEで、LatitudeとLongitudeが欠損している行を埋める
test.loc[(test['City'] == 'COUSHATTA') & (test['Latitude'].isna()), 'Latitude'] = COUSHATTA_latitude
test.loc[(test['City'] == 'COUSHATTA') & (test['Longitude'].isna()), 'Longitude'] = COUSHATTA_longitude

# %%
# PLEASANT FARMSの緯度と経度の値を定義
PLEASANT_FARMS_latitude = 31.863530
PLEASANT_FARMS_longitude = -99.492638

# CityがMACKSVILLEで、LatitudeとLongitudeが欠損している行を埋める
test.loc[(test['City'] == 'PLEASANT FARMS') & (test['Latitude'].isna()), 'Latitude'] = PLEASANT_FARMS_latitude
test.loc[(test['City'] == 'PLEASANT FARMS') & (test['Longitude'].isna()), 'Longitude'] = PLEASANT_FARMS_longitude

# %%
# COUNSELORの緯度と経度の値を定義
COUNSELOR_latitude = 34.166197
COUNSELOR_longitude = -106.026237

# CityがMACKSVILLEで、LatitudeとLongitudeが欠損している行を埋める
test.loc[(test['City'] == 'COUNSELOR') & (test['Latitude'].isna()), 'Latitude'] = COUNSELOR_latitude
test.loc[(test['City'] == 'COUNSELOR') & (test['Longitude'].isna()), 'Longitude'] = COUNSELOR_longitude

# %%
# BLANCOの緯度と経度の値を定義
BLANCO_latitude = 36.724172
BLANCO_longitude = -107.82534

# CityがMACKSVILLEで、LatitudeとLongitudeが欠損している行を埋める
test.loc[(test['City'] == 'BLANCO') & (test['Latitude'].isna()), 'Latitude'] = BLANCO_latitude
test.loc[(test['City'] == 'BLANCO') & (test['Longitude'].isna()), 'Longitude'] = BLANCO_longitude

# %%
# TRIADELPHIAの緯度と経度の値を定義
TRIADELPHIA_latitude = 40.049755
TRIADELPHIA_longitude = -80.624379

# CityがMACKSVILLEで、LatitudeとLongitudeが欠損している行を埋める
test.loc[(test['City'] == 'TRIADELPHIA') & (test['Latitude'].isna()), 'Latitude'] = TRIADELPHIA_latitude
test.loc[(test['City'] == 'TRIADELPHIA') & (test['Longitude'].isna()), 'Longitude'] = TRIADELPHIA_longitude

# %%
# SALTFLATの緯度と経度の値を定義
SALTFLAT_latitude = 31.74547
SALTFLAT_longitude = -105.081255

# CityがMACKSVILLEで、LatitudeとLongitudeが欠損している行を埋める
test.loc[(test['City'] == 'SALT FLAT') & (test['Latitude'].isna()), 'Latitude'] = SALTFLAT_latitude
test.loc[(test['City'] == 'SALT FLAT') & (test['Longitude'].isna()), 'Longitude'] = SALTFLAT_longitude

# %%
# WESTCLAYの緯度と経度の値を定義
WESTCLAY_latitude = 37.735495
WESTCLAY_longitude = -85.87114

# CityがMACKSVILLEで、LatitudeとLongitudeが欠損している行を埋める
test.loc[(test['City'] == 'WEST CLAY') & (test['Latitude'].isna()), 'Latitude'] = WESTCLAY_latitude
test.loc[(test['City'] == 'WEST CLAY') & (test['Longitude'].isna()), 'Longitude'] = WESTCLAY_longitude

# %%
# PRUDHOEBAYの緯度と経度の値を定義
PRUDHOEBAY_latitude = 70.326653
PRUDHOEBAY_longitude = -148.82165

# CityがMACKSVILLEで、LatitudeとLongitudeが欠損している行を埋める
test.loc[(test['City'] == 'PRUDHOE BAY') & (test['Latitude'].isna()), 'Latitude'] = PRUDHOEBAY_latitude
test.loc[(test['City'] == 'PRUDHOE BAY') & (test['Longitude'].isna()), 'Longitude'] = PRUDHOEBAY_longitude

# %%
test['IndustryType'].value_counts()

# %%
test['Power Plants'] = test['IndustryType'].str.contains('Power Plants').astype(int)
test['Power Plants'].value_counts()

# %%
test['Petroleum'] = test['IndustryType'].str.contains('Petroleum').astype(int)
test['Petroleum'].value_counts()

# %%
test['Natural Gas'] = test['IndustryType'].str.contains('Natural Gas').astype(int)
test['Natural Gas'].value_counts()

# %%
test['Industrial Gas'] = test['IndustryType'].str.contains('Industrial Gas').astype(int)
test['Industrial Gas'].value_counts()

# %%
test['Minerals'] = test['IndustryType'].str.contains('Minerals').astype(int)
test['Minerals'].value_counts()

# %%
test['Chemicals'] = test['IndustryType'].str.contains('Chemicals').astype(int)
test['Chemicals'].value_counts()

# %%
test['Metals'] = test['IndustryType'].str.contains('Metals').astype(int)
test['Metals'].value_counts()

# %%
test['Refineries'] = test['IndustryType'].str.contains('Refineries').astype(int)
test['Refineries'].value_counts()

# %%
test['Pulp and Paper'] = test['IndustryType'].str.contains('Pulp and Paper').astype(int)
test['Pulp and Paper'].value_counts()

# %%
test['Suppliers of CO2'] = test['IndustryType'].str.contains('Suppliers of CO2').astype(int)
test['Suppliers of CO2'].value_counts()

# %%
test['Injection of CO2'] = test['IndustryType'].str.contains('Injection of CO2').astype(int)
test['Injection of CO2'].value_counts()

# %%
test['Import and Export of Equipment Containing Fluorintaed GHGs'] = test['IndustryType'].str.contains('Import and Export of Equipment Containing Fluorintaed GHGs').astype(int)
test['Import and Export of Equipment Containing Fluorintaed GHGs'].value_counts()

# %%
test['Waste'] = test['IndustryType'].str.contains('Waste').astype(int)
test['Waste'].value_counts()

# %%
test['Other'] = test['IndustryType'].str.contains('Other').astype(int)
test['Other'].value_counts()

# %%
test.info()

# %%
test.isnull().sum()

# %% [markdown]
# ## TRI 欠損値埋め

# %%
# 工業別毎にその最頻値でTRI10の欠損値を埋める
industry_mode = test.groupby('IndustryType')['TRI_Air_Emissions_10_in_lbs'].apply(lambda x: x.mode()[0] if len(x.mode()) > 0 else None)

# 各IndustryTypeのフラグがTrueの行について、TRIの欠損値を対応する最頻値で埋める
for industry in industry_mode.index:
    test.loc[(test['IndustryType'] == industry) & (test['TRI_Air_Emissions_10_in_lbs'].isna()), 'TRI_Air_Emissions_10_in_lbs'] = industry_mode[industry]

# 工業別毎にその最頻値でTRI11の欠損値を埋める
industry_mode = test.groupby('IndustryType')['TRI_Air_Emissions_11_in_lbs'].apply(lambda x: x.mode()[0] if len(x.mode()) > 0 else None)

# 各IndustryTypeのフラグがTrueの行について、TRIの欠損値を対応する最頻値で埋める
for industry in industry_mode.index:
    test.loc[(test['IndustryType'] == industry) & (test['TRI_Air_Emissions_11_in_lbs'].isna()), 'TRI_Air_Emissions_11_in_lbs'] = industry_mode[industry]

# 工業別毎にその最頻値でTRI12の欠損値を埋める
industry_mode = test.groupby('IndustryType')['TRI_Air_Emissions_12_in_lbs'].apply(lambda x: x.mode()[0] if len(x.mode()) > 0 else None)

# 各IndustryTypeのフラグがTrueの行について、TRIの欠損値を対応する最頻値で埋める
for industry in industry_mode.index:
    test.loc[(test['IndustryType'] == industry) & (test['TRI_Air_Emissions_12_in_lbs'].isna()), 'TRI_Air_Emissions_12_in_lbs'] = industry_mode[industry]

# 工業別毎にその最頻値でTRI13の欠損値を埋める
industry_mode = test.groupby('IndustryType')['TRI_Air_Emissions_13_in_lbs'].apply(lambda x: x.mode()[0] if len(x.mode()) > 0 else None)

# 各IndustryTypeのフラグがTrueの行について、TRIの欠損値を対応する最頻値で埋める
for industry in industry_mode.index:
    test.loc[(test['IndustryType'] == industry) & (test['TRI_Air_Emissions_13_in_lbs'].isna()), 'TRI_Air_Emissions_13_in_lbs'] = industry_mode[industry]

# %%
test.isnull().sum()

# %% [markdown]
# ## 分岐点

# %%
# まだTRIに関して欠損値があるので(とりあえず)全体の最頻値で埋める
test.loc[(test['TRI_Air_Emissions_10_in_lbs'].isna()), 'TRI_Air_Emissions_10_in_lbs'] = test['TRI_Air_Emissions_10_in_lbs'].mode()[0]
test.loc[(test['TRI_Air_Emissions_11_in_lbs'].isna()), 'TRI_Air_Emissions_11_in_lbs'] = test['TRI_Air_Emissions_11_in_lbs'].mode()[0]
test.loc[(test['TRI_Air_Emissions_12_in_lbs'].isna()), 'TRI_Air_Emissions_12_in_lbs'] = test['TRI_Air_Emissions_12_in_lbs'].mode()[0]
test.loc[(test['TRI_Air_Emissions_13_in_lbs'].isna()), 'TRI_Air_Emissions_13_in_lbs'] = test['TRI_Air_Emissions_13_in_lbs'].mode()[0]

# %%
test.isnull().sum()

# %% [markdown]
# ## GHG 欠損値埋め

# %%
# 工業別毎にその最頻値でGHG10の欠損値を埋める
industry_GHG_mode10 = test.groupby('IndustryType')['GHG_Direct_Emissions_10_in_metric_tons'].apply(lambda x: x.mode()[0] if len(x.mode()) > 0 else None)

# 各IndustryTypeのフラグがTrueの行について、GHGの欠損値を対応する最頻値で埋める
for industry in industry_GHG_mode10.index:
    test.loc[(test['IndustryType'] == industry) & (test['GHG_Direct_Emissions_10_in_metric_tons'].isna()), 'GHG_Direct_Emissions_10_in_metric_tons'] = industry_GHG_mode10[industry]

# 工業別毎にその最頻値でGHG11の欠損値を埋める
industry_GHG_mode11 = test.groupby('IndustryType')['GHG_Direct_Emissions_11_in_metric_tons'].apply(lambda x: x.mode()[0] if len(x.mode()) > 0 else None)

# 各IndustryTypeのフラグがTrueの行について、TRIの欠損値を対応する最頻値で埋める
for industry in industry_GHG_mode11.index:
    test.loc[(test['IndustryType'] == industry) & (test['GHG_Direct_Emissions_11_in_metric_tons'].isna()), 'GHG_Direct_Emissions_11_in_metric_tons'] = industry_GHG_mode11[industry]

# 工業別毎にその最頻値でGHG12の欠損値を埋める
industry_GHG_mode12 = test.groupby('IndustryType')['GHG_Direct_Emissions_12_in_metric_tons'].apply(lambda x: x.mode()[0] if len(x.mode()) > 0 else None)

# 各IndustryTypeのフラグがTrueの行について、TRIの欠損値を対応する最頻値で埋める
for industry in industry_GHG_mode12.index:
    test.loc[(test['IndustryType'] == industry) & (test['GHG_Direct_Emissions_12_in_metric_tons'].isna()), 'GHG_Direct_Emissions_12_in_metric_tons'] = industry_GHG_mode12[industry]

# 工業別毎にその最頻値でGHG13の欠損値を埋める
industry_GHG_mode13 = test.groupby('IndustryType')['GHG_Direct_Emissions_13_in_metric_tons'].apply(lambda x: x.mode()[0] if len(x.mode()) > 0 else None)

# 各IndustryTypeのフラグがTrueの行について、TRIの欠損値を対応する最頻値で埋める
for industry in industry_GHG_mode13.index:
    test.loc[(test['IndustryType'] == industry) & (test['GHG_Direct_Emissions_13_in_metric_tons'].isna()), 'GHG_Direct_Emissions_13_in_metric_tons'] = industry_GHG_mode13[industry]

# %%
test.isnull().sum()

# %%
test.loc[(test['GHG_Direct_Emissions_10_in_metric_tons'].isna()),['GHG_Direct_Emissions_10_in_metric_tons','GHG_Direct_Emissions_11_in_metric_tons','GHG_Direct_Emissions_12_in_metric_tons','GHG_Direct_Emissions_13_in_metric_tons']]

# %%
test.loc[(test['GHG_Direct_Emissions_10_in_metric_tons'].isna()),'GHG_Direct_Emissions_10_in_metric_tons'] = 56745.619152 + 4366.7636695
# 理由は以下

# %%
56745.619152 - 52059.934068

# %%
52059.934068 - 48012.091813

# %%
np.mean([4685.685083999997,4047.842255000003])

# %%
test.isnull().sum()

# %% [markdown]
# # train学習

# %%
train = train.dropna(subset=['Latitude'])

# %%
train = train.dropna(subset=['IndustryType'])

# %%
train['IndustryType'].value_counts()

# %%
train['Power Plants'] = train['IndustryType'].str.contains('Power Plants').astype(int)
train['Power Plants'].value_counts()

# %%
train['Petroleum'] = train['IndustryType'].str.contains('Petroleum').astype(int)
train['Petroleum'].value_counts()

# %%
train['Natural Gas'] = train['IndustryType'].str.contains('Natural Gas').astype(int)
train['Natural Gas'].value_counts()

# %%
train['Industrial Gas'] = train['IndustryType'].str.contains('Industrial Gas').astype(int)
train['Industrial Gas'].value_counts()

# %%
train['Minerals'] = train['IndustryType'].str.contains('Minerals').astype(int)
train['Minerals'].value_counts()

# %%
train['Chemicals'] = train['IndustryType'].str.contains('Chemicals').astype(int)
train['Chemicals'].value_counts()

# %%
train['Metals'] = train['IndustryType'].str.contains('Metals').astype(int)
train['Metals'].value_counts()

# %%
train['Refineries'] = train['IndustryType'].str.contains('Refineries').astype(int)
train['Refineries'].value_counts()

# %%
train['Pulp and Paper'] = train['IndustryType'].str.contains('Pulp and Paper').astype(int)
train['Pulp and Paper'].value_counts()

# %%
train['Suppliers of CO2'] = train['IndustryType'].str.contains('Suppliers of CO2').astype(int)
train['Suppliers of CO2'].value_counts()

# %%
train['Injection of CO2'] = train['IndustryType'].str.contains('Injection of CO2').astype(int)
train['Injection of CO2'].value_counts()

# %%
train['Import and Export of Equipment Containing Fluorintaed GHGs'] = train['IndustryType'].str.contains('Import and Export of Equipment Containing Fluorintaed GHGs').astype(int)
train['Import and Export of Equipment Containing Fluorintaed GHGs'].value_counts()

# %%
train['Coal-based Liquid Fuel Supply'] = train['IndustryType'].str.contains('Coal-based Liquid Fuel Supply').astype(int)
train['Coal-based Liquid Fuel Supply'].value_counts()

# %%
train['Waste'] = train['IndustryType'].str.contains('Waste').astype(int)
train['Waste'].value_counts()

# %%
train['Other'] = train['IndustryType'].str.contains('Other').astype(int)
train['Other'].value_counts()

# %%
train.dropna(subset = ['TRI_Air_Emissions_10_in_lbs'], inplace = True )

# %%
import numpy as np
import pandas as pd
from catboost import CatBoostRegressor
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.metrics import make_scorer

def rmsle(y_true, y_pred):
    log_y_true = np.log1p(y_true)
    log_y_pred = np.log1p(y_pred)
    return np.sqrt(np.mean((log_y_true - log_y_pred) ** 2))

# RMSLE用のスコア関数を作成
rmsle_scorer = make_scorer(rmsle, greater_is_better=False)

# 説明変数と目的変数のセット
X = train[['Latitude', 'Longitude', 'Power Plants', 'Petroleum', 'Natural Gas',
           'Industrial Gas', 'Minerals', 'Chemicals', 'Metals', 'Refineries',
           'Pulp and Paper', 'Suppliers of CO2', 'Injection of CO2',
           'Import and Export of Equipment Containing Fluorintaed GHGs',
           'Coal-based Liquid Fuel Supply', 'Other', 'Waste',
           'TRI_Air_Emissions_10_in_lbs', 'TRI_Air_Emissions_11_in_lbs',
           'TRI_Air_Emissions_12_in_lbs', 'TRI_Air_Emissions_13_in_lbs',
           'GHG_Direct_Emissions_10_in_metric_tons', 'GHG_Direct_Emissions_11_in_metric_tons',
           'GHG_Direct_Emissions_12_in_metric_tons', 'GHG_Direct_Emissions_13_in_metric_tons']]
Y = train['GHG_Direct_Emissions_14_in_metric_tons']  # 目的変数（連続値）

# CatBoostのハイパーパラメータの候補
param_grid = {
    'depth': [6, 8, 10],
    'learning_rate': [0.1, 0.15, 0.2],
    'iterations': [70, 75, 80]
}

# k-Fold交差検証の設定
kf = KFold(n_splits=10, shuffle=True, random_state=42)
rmsle_scores = []

for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    Y_train, Y_test = Y.iloc[train_index], Y.iloc[test_index]

    # CatBoostモデルを作成
    cat_model = CatBoostRegressor(random_state=42, verbose=0)

    # グリッドサーチの設定
    grid_search = GridSearchCV(
        estimator=cat_model,
        param_grid=param_grid,
        scoring=rmsle_scorer,
        cv=3,  # グリッドサーチの内部で使用するクロスバリデーションの分割数
        verbose=1
    )

    # グリッドサーチでハイパーパラメータを最適化
    grid_search.fit(X_train, Y_train)

    # 最適モデルを用いてテストデータを予測
    best_model = grid_search.best_estimator_
    y_test_pred = best_model.predict(X_test)

    # RMSLEの評価
    rmsle_score = rmsle(Y_test, y_test_pred)
    rmsle_scores.append(rmsle_score)

# 平均RMSLEの表示
print("Average RMSLE:", np.mean(rmsle_scores))
print("Best Parameters:", grid_search.best_params_)

# %%
display(y_test_pred)

# %%
X_true_test = test[['Latitude', 'Longitude', 'Power Plants', 'Petroleum', 'Natural Gas',
           'Industrial Gas', 'Minerals', 'Chemicals', 'Metals', 'Refineries',
           'Pulp and Paper', 'Suppliers of CO2', 'Injection of CO2',
           'Import and Export of Equipment Containing Fluorintaed GHGs',
            'Other', 'Waste',
           'TRI_Air_Emissions_10_in_lbs', 'TRI_Air_Emissions_11_in_lbs',
           'TRI_Air_Emissions_12_in_lbs', 'TRI_Air_Emissions_13_in_lbs',
           'GHG_Direct_Emissions_10_in_metric_tons', 'GHG_Direct_Emissions_11_in_metric_tons',
           'GHG_Direct_Emissions_12_in_metric_tons', 'GHG_Direct_Emissions_13_in_metric_tons']]

y_true_test_pred = cat_model.predict(X_true_test)

# %%
predict = pd.DataFrame(y_true_test_pred)
display(predict)

# %%
predict.to_csv('signate_SMBC_submit_ver1.csv', index=False)

# %% [markdown]
# ## 対数変換ver

# %%
import numpy as np
import pandas as pd
from catboost import CatBoostRegressor
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.metrics import make_scorer

# RMSLEの計算関数
def rmsle(y_true, y_pred):
    log_y_true = np.log1p(y_true)
    log_y_pred = np.log1p(y_pred)
    return np.sqrt(np.mean((log_y_true - log_y_pred) ** 2))

# RMSLE用のスコア関数を作成
rmsle_scorer = make_scorer(rmsle, greater_is_better=False)

# 説明変数と目的変数のセット
X = train[['Latitude', 'Longitude', 'Power Plants', 'Petroleum', 'Natural Gas',
           'Industrial Gas', 'Minerals', 'Chemicals', 'Metals', 'Refineries',
           'Pulp and Paper', 'Suppliers of CO2', 'Injection of CO2',
           'Import and Export of Equipment Containing Fluorintaed GHGs',
           'Coal-based Liquid Fuel Supply', 'Other', 'Waste',
           'TRI_Air_Emissions_10_in_lbs', 'TRI_Air_Emissions_11_in_lbs',
           'TRI_Air_Emissions_12_in_lbs', 'TRI_Air_Emissions_13_in_lbs',
           'GHG_Direct_Emissions_10_in_metric_tons', 'GHG_Direct_Emissions_11_in_metric_tons',
           'GHG_Direct_Emissions_12_in_metric_tons', 'GHG_Direct_Emissions_13_in_metric_tons']]
Y = train['GHG_Direct_Emissions_14_in_metric_tons']  # 目的変数（連続値）

# 歪んだ特徴量に対して対数変換を行う
skewed_features = ['TRI_Air_Emissions_10_in_lbs', 'TRI_Air_Emissions_11_in_lbs',
                   'TRI_Air_Emissions_12_in_lbs', 'TRI_Air_Emissions_13_in_lbs',
                   'GHG_Direct_Emissions_10_in_metric_tons', 'GHG_Direct_Emissions_11_in_metric_tons',
                   'GHG_Direct_Emissions_12_in_metric_tons', 'GHG_Direct_Emissions_13_in_metric_tons']

X[skewed_features] = X[skewed_features].apply(lambda x: np.log1p(x))

# CatBoostのハイパーパラメータの候補
param_grid = {
    'depth': [6, 8, 10],
    'learning_rate': [0.1, 0.15, 0.2],
    'iterations': [70, 75, 80]
}

# k-Fold交差検証の設定
kf = KFold(n_splits=10, shuffle=True, random_state=42)
rmsle_scores = []

for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    Y_train, Y_test = Y.iloc[train_index], Y.iloc[test_index]

    # CatBoostモデルを作成
    cat_model = CatBoostRegressor(random_state=42, verbose=0)

    # グリッドサーチの設定
    grid_search = GridSearchCV(
        estimator=cat_model,
        param_grid=param_grid,
        scoring=rmsle_scorer,
        cv=3,  # グリッドサーチの内部で使用するクロスバリデーションの分割数
        verbose=1
    )

    # グリッドサーチでハイパーパラメータを最適化
    grid_search.fit(X_train, Y_train)

    # 最適モデルを用いてテストデータを予測
    best_model = grid_search.best_estimator_
    y_test_pred = best_model.predict(X_test)

    # RMSLEの評価
    rmsle_score = rmsle(Y_test, y_test_pred)
    rmsle_scores.append(rmsle_score)

# 平均RMSLEの表示
print("Average RMSLE:", np.mean(rmsle_scores))
print("Best Parameters:", grid_search.best_params_)

# %%
import numpy as np
import pandas as pd
from catboost import CatBoostRegressor
from sklearn.model_selection import KFold

# 説明変数と目的変数のセット
X = train[['Latitude', 'Longitude', 'Power Plants', 'Petroleum', 'Natural Gas',
           'Industrial Gas', 'Minerals', 'Chemicals', 'Metals', 'Refineries',
           'Pulp and Paper', 'Suppliers of CO2', 'Injection of CO2',
           'Import and Export of Equipment Containing Fluorintaed GHGs',
           'Coal-based Liquid Fuel Supply', 'Other', 'Waste',
           'TRI_Air_Emissions_10_in_lbs', 'TRI_Air_Emissions_11_in_lbs',
           'TRI_Air_Emissions_12_in_lbs', 'TRI_Air_Emissions_13_in_lbs',
           'GHG_Direct_Emissions_10_in_metric_tons', 'GHG_Direct_Emissions_11_in_metric_tons',
           'GHG_Direct_Emissions_12_in_metric_tons', 'GHG_Direct_Emissions_13_in_metric_tons']]
Y = train['GHG_Direct_Emissions_14_in_metric_tons']  # 目的変数（連続値）

# 歪んだ特徴量に対して対数変換を行う
skewed_features = ['TRI_Air_Emissions_10_in_lbs', 'TRI_Air_Emissions_11_in_lbs',
                   'TRI_Air_Emissions_12_in_lbs', 'TRI_Air_Emissions_13_in_lbs',
                   'GHG_Direct_Emissions_10_in_metric_tons', 'GHG_Direct_Emissions_11_in_metric_tons',
                   'GHG_Direct_Emissions_12_in_metric_tons', 'GHG_Direct_Emissions_13_in_metric_tons']

X[skewed_features] = X[skewed_features].apply(lambda x: np.log1p(x))

# k-Fold交差検証の設定
kf = KFold(n_splits=10, shuffle=True, random_state=42)
scores = []

for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    Y_train, Y_test = Y.iloc[train_index], Y.iloc[test_index]

    # CatBoostモデルを作成
    cat_model2 = CatBoostRegressor(
        depth=6,
        iterations=80,
        learning_rate=0.1,
        random_state=42,
        verbose=0
    )

    # モデルを訓練
    cat_model2.fit(X_train, Y_train)

    # テストデータを予測
    y_test_pred = cat_model2.predict(X_test)

# %%
test.info()

# %%
X_true_test2 = test[['Latitude', 'Longitude', 'Power Plants', 'Petroleum', 'Natural Gas',
           'Industrial Gas', 'Minerals', 'Chemicals', 'Metals', 'Refineries',
           'Pulp and Paper', 'Suppliers of CO2', 'Injection of CO2',
           'Import and Export of Equipment Containing Fluorintaed GHGs',
            'Other', 'Waste',
           'TRI_Air_Emissions_10_in_lbs', 'TRI_Air_Emissions_11_in_lbs',
           'TRI_Air_Emissions_12_in_lbs', 'TRI_Air_Emissions_13_in_lbs',
           'GHG_Direct_Emissions_10_in_metric_tons', 'GHG_Direct_Emissions_11_in_metric_tons',
           'GHG_Direct_Emissions_12_in_metric_tons', 'GHG_Direct_Emissions_13_in_metric_tons']]

# 歪んだ特徴量に対して対数変換を行う
skewed_features = ['TRI_Air_Emissions_10_in_lbs', 'TRI_Air_Emissions_11_in_lbs',
                   'TRI_Air_Emissions_12_in_lbs', 'TRI_Air_Emissions_13_in_lbs',
                   'GHG_Direct_Emissions_10_in_metric_tons', 'GHG_Direct_Emissions_11_in_metric_tons',
                   'GHG_Direct_Emissions_12_in_metric_tons', 'GHG_Direct_Emissions_13_in_metric_tons']

X_true_test2[skewed_features] = X_true_test2[skewed_features].apply(lambda x: np.log1p(x))

y_true_test_pred2 = cat_model2.predict(X_true_test2)

# %%
predict2 = pd.DataFrame(y_true_test_pred2)
display(predict2)

# %%
# リッジ回帰のみで分析

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.metrics import make_scorer

def rmsle(y_true, y_pred):
    log_y_true = np.log1p(y_true)
    log_y_pred = np.log1p(y_pred)
    return np.sqrt(np.mean((log_y_true - log_y_pred) ** 2))

# RMSLE用のスコア関数を作成
rmsle_scorer = make_scorer(rmsle, greater_is_better=False)

# 説明変数と目的変数のセット
X = train[['Latitude', 'Longitude', 'Power Plants', 'Petroleum', 'Natural Gas',
           'Industrial Gas', 'Minerals', 'Chemicals', 'Metals', 'Refineries',
           'Pulp and Paper', 'Suppliers of CO2', 'Injection of CO2',
           'Import and Export of Equipment Containing Fluorintaed GHGs',
           'Coal-based Liquid Fuel Supply', 'Other', 'Waste',
           'TRI_Air_Emissions_10_in_lbs', 'TRI_Air_Emissions_11_in_lbs',
           'TRI_Air_Emissions_12_in_lbs', 'TRI_Air_Emissions_13_in_lbs',
           'GHG_Direct_Emissions_10_in_metric_tons', 'GHG_Direct_Emissions_11_in_metric_tons',
           'GHG_Direct_Emissions_12_in_metric_tons', 'GHG_Direct_Emissions_13_in_metric_tons']]
Y = train['GHG_Direct_Emissions_14_in_metric_tons']  # 目的変数（連続値）

# リッジ回帰のハイパーパラメータの候補
param_grid = {
    'alpha': [43.25, 44.125, 45.0]
}

# k-Fold交差検証の設定
kf = KFold(n_splits=10, shuffle=True, random_state=42)
rmsle_scores = []

for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    Y_train, Y_test = Y.iloc[train_index], Y.iloc[test_index]

    # リッジ回帰モデルを作成
    ridge_model = Ridge()

    # グリッドサーチの設定
    grid_search = GridSearchCV(
        estimator=ridge_model,
        param_grid=param_grid,
        scoring=rmsle_scorer,
        cv=3,  # グリッドサーチの内部で使用するクロスバリデーションの分割数
        verbose=1
    )

    # グリッドサーチでハイパーパラメータを最適化
    grid_search.fit(X_train, Y_train)

    # 最適モデルを用いてテストデータを予測
    best_model = grid_search.best_estimator_
    y_test_pred = best_model.predict(X_test)

    # RMSLEの評価
    rmsle_score = rmsle(Y_test, y_test_pred)
    rmsle_scores.append(rmsle_score)

# 平均RMSLEの表示
print("Average RMSLE:", np.mean(rmsle_scores))
print("Best Parameters:", grid_search.best_params_)

# %%
# cat boostとリッジ回帰を半分にして分析

# %%
import numpy as np
import pandas as pd
from catboost import CatBoostRegressor
from sklearn.linear_model import Ridge
from sklearn.model_selection import KFold

# 説明変数と目的変数のセット
X = train[['Latitude', 'Longitude', 'Power Plants', 'Petroleum', 'Natural Gas',
           'Industrial Gas', 'Minerals', 'Chemicals', 'Metals', 'Refineries',
           'Pulp and Paper', 'Suppliers of CO2', 'Injection of CO2',
           'Import and Export of Equipment Containing Fluorintaed GHGs',
           'Coal-based Liquid Fuel Supply', 'Other', 'Waste',
           'TRI_Air_Emissions_10_in_lbs', 'TRI_Air_Emissions_11_in_lbs',
           'TRI_Air_Emissions_12_in_lbs', 'TRI_Air_Emissions_13_in_lbs',
           'GHG_Direct_Emissions_10_in_metric_tons', 'GHG_Direct_Emissions_11_in_metric_tons',
           'GHG_Direct_Emissions_12_in_metric_tons', 'GHG_Direct_Emissions_13_in_metric_tons']]
Y = train['GHG_Direct_Emissions_14_in_metric_tons']  # 目的変数（連続値）

# k-Fold交差検証の設定
kf = KFold(n_splits=10, shuffle=True, random_state=42)
scores = []

for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    Y_train, Y_test = Y.iloc[train_index], Y.iloc[test_index]

    # CatBoostモデルを作成
    cat_model = CatBoostRegressor(
        depth=6,
        iterations=80,
        learning_rate=0.1,
        random_state=42,
        verbose=0
    )

    # モデルを訓練
    cat_model.fit(X_train, Y_train)

    # テストデータを予測
    y_test_pred_catboost = cat_model.predict(X_test)

    # L2正則化（リッジ回帰）モデルを作成
    ridge_model = Ridge(alpha=1.0)  # alphaは正則化の強さを制御するパラメータ
    ridge_model.fit(X_train, Y_train)

    # テストデータを予測
    y_test_pred_ridge = ridge_model.predict(X_test)

    # CatBoostとリッジ回帰の予測結果を組み合わせる（例: 平均を取る）
    y_test_pred_combined = (y_test_pred_catboost + y_test_pred_ridge) / 2

    # RMSLEの評価
    rmsle_score = rmsle(Y_test, y_test_pred_combined)
    rmsle_scores.append(rmsle_score)

# 平均RMSLEの表示
print("Average RMSLE:", np.mean(rmsle_scores))
print("Best Parameters:", grid_search.best_params_)
